# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Simon Wamai
# * Student pace: full time Remote
# * Scheduled project review date/time:
# * Instructor name: Lucille
# * Blog post URL:

# %% [markdown]
# Project Overview
# For this project, you will use data cleaning, imputation, analysis, and visualization to generate
# insights for a business stakeholder.
#
# Business Problem
# Your company is expanding in to new industries to diversify its portfolio. Specifically,
# they are interested in purchasing and operating airplanes for commercial and private enterprises,
# but do not know anything about the potential risks of aircraft.
# You are charged with determining which aircraft are the lowest risk for the company to
# start this new business endeavor. You must then translate your findings into actionable insights
# that the head of the new aviation division can use to help decide which aircraft to purchase.

# %%
#Import necessary libraries and set matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load in the data
df = pd.read_csv('AviationData.csv', encoding='latin-1', low_memory = False);
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country   Latitude   Longitude Airport.Code  \
# 0      MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1       BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2        Saltville, VA  United States  36.922223  -81.878056          NaN
# 3           EUREKA, CA  United States        NaN         NaN          NaN
# 4           Canton, OH  United States        NaN         NaN          NaN
# ...                ...            ...        ...         ...          ...
# 88884    Annapolis, MD  United States        NaN         NaN          NaN
# 88885      Hampton, NH  United States        NaN         NaN          NaN
# 88886       Payson, AZ  United States    341525N    1112021W          PAN
# 88887       Morgan, UT  United States        NaN         NaN          NaN
# 88888       Athens, GA  United States        NaN         NaN          NaN
#
#       Airport.Name  ... Purpose.of.flight         Air.carrier  \
# 0              NaN  ...          Personal                 NaN
# 1              NaN  ...          Personal                 NaN
# 2              NaN  ...          Personal                 NaN
# 3              NaN  ...          Personal                 NaN
# 4              NaN  ...          Personal                 NaN
# ...            ...  ...               ...                 ...
# 88884          NaN  ...          Personal                 NaN
# 88885          NaN  ...               NaN                 NaN
# 88886       PAYSON  ...          Personal                 NaN
# 88887          NaN  ...          Personal  MC CESSNA 210N LLC
# 88888          NaN  ...          Personal                 NaN
#
#       Total.Fatal.Injuries Total.Serious.Injuries Total.Minor.Injuries  \
# 0                      2.0                    0.0                  0.0
# 1                      4.0                    0.0                  0.0
# 2                      3.0                    NaN                  NaN
# 3                      2.0                    0.0                  0.0
# 4                      1.0                    2.0                  NaN
# ...                    ...                    ...                  ...
# 88884                  0.0                    1.0                  0.0
# 88885                  0.0                    0.0                  0.0
# 88886                  0.0                    0.0                  0.0
# 88887                  0.0                    0.0                  0.0
# 88888                  0.0                    1.0                  0.0
#
#       Total.Uninjured Weather.Condition  Broad.phase.of.flight  \
# 0                 0.0               UNK                 Cruise
# 1                 0.0               UNK                Unknown
# 2                 NaN               IMC                 Cruise
# 3                 0.0               IMC                 Cruise
# 4                 0.0               VMC               Approach
# ...               ...               ...                    ...
# 88884             0.0               NaN                    NaN
# 88885             0.0               NaN                    NaN
# 88886             1.0               VMC                    NaN
# 88887             0.0               NaN                    NaN
# 88888             1.0               NaN                    NaN
#
#         Report.Status Publication.Date
# 0      Probable Cause              NaN
# 1      Probable Cause       19-09-1996
# 2      Probable Cause       26-02-2007
# 3      Probable Cause       12-09-2000
# 4      Probable Cause       16-04-1980
# ...               ...              ...
# 88884             NaN       29-12-2022
# 88885             NaN              NaN
# 88886             NaN       27-12-2022
# 88887             NaN              NaN
# 88888             NaN       30-12-2022
#
# [88889 rows x 31 columns]

# %% [markdown]
# Check for the dataframes information by .dtypes and .describe

# %%
#chek for the data type
df.dtypes
# Out:
# Event.Id                   object
# Investigation.Type         object
# Accident.Number            object
# Event.Date                 object
# Location                   object
# Country                    object
# Latitude                   object
# Longitude                  object
# Airport.Code               object
# Airport.Name               object
# Injury.Severity            object
# Aircraft.damage            object
# Aircraft.Category          object
# Registration.Number        object
# Make                       object
# Model                      object
# Amateur.Built              object
# Number.of.Engines         float64
# Engine.Type                object
# FAR.Description            object
# Schedule                   object
# Purpose.of.flight          object
# Air.carrier                object
# Total.Fatal.Injuries      float64
# Total.Serious.Injuries    float64
# Total.Minor.Injuries      float64
# Total.Uninjured           float64
# Weather.Condition          object
# Broad.phase.of.flight      object
# Report.Status              object
# Publication.Date           object
# dtype: object

# %%
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# 75%                0.000000         2.000000
# max              380.000000       699.000000

# %% [markdown]
# First get a copy of the dataframe where the country is USA and purpose of flight is business.
# The presumptions are;
# 1.The company wants to set up its operations in the USA, and not to operate abroad.
# 2.The company is setting up for business operations, thus we only consider for 'Business' and not 'Personal'

# %%
# Filter the data by country and purpose of flight
df = df[(df['Country'] == 'United States') & (df['Purpose.of.flight'] == 'Business')].copy()
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 8      20020909X01561           Accident      NYC82DA015  1982-01-01
# 25     20020917X01905           Accident      DCA82AA008  1982-01-03
# 37     20020917X02304           Accident      LAX82FUM06  1982-01-05
# 40     20020917X01764           Incident      ATL82IA029  1982-01-05
# 41     20020917X01993           Accident      FTW82DA037  1982-01-05
# ...               ...                ...             ...         ...
# 88765  20221109106270           Accident      CEN23FA031  2022-11-09
# 88786  20221115106296           Accident      CEN23LA037  2022-11-15
# 88804  20221121106337           Accident      ANC23LA006  2022-11-20
# 88834  20221130106387           Accident      CEN23LA056  2022-11-29
# 88867  20221213106456           Accident      WPR23LA066  2022-12-12
#
#                Location        Country Latitude Longitude Airport.Code  \
# 8      EAST HANOVER, NJ  United States      NaN       NaN          N58
# 25          ASHLAND, VA  United States      NaN       NaN          NaN
# 37           RAMONA, CA  United States      NaN       NaN          L39
# 40        PENSACOLA, FL  United States      NaN       NaN          NaN
# 41           LONOKE, AR  United States      NaN       NaN          NaN
# ...                 ...            ...      ...       ...          ...
# 88765       Bignell, NE  United States  041453N  1003648W          LBF
# 88786      Pewaukee, WI  United States  043228N  0881413W          UES
# 88804        Bethel, AK  United States  604243N  1614111W          NaN
# 88834    Batesville, AR  United States  354334N  0913851W          BVX
# 88867       Redding, CA  United States  039101N  0121410W          RDD
#
#                          Airport.Name  ... Purpose.of.flight  \
# 8                             HANOVER  ...          Business
# 25                     HANOVER COUNTY  ...          Business
# 37                             RAMONA  ...          Business
# 40                                NaN  ...          Business
# 41                                NaN  ...          Business
# ...                               ...  ...               ...
# 88765  NORTH PLATTE RGNL/LEE BIRD FLD  ...          Business
# 88786                 WAUKESHA COUNTY  ...          Business
# 88804                             NaN  ...          Business
# 88834     Batesville Regional Airport  ...          Business
# 88867                             NaN  ...          Business
#
#                           Air.carrier Total.Fatal.Injuries  \
# 8                                 NaN                  0.0
# 25                                NaN                  8.0
# 37                                NaN                  3.0
# 40                                NaN                  0.0
# 41                                NaN                  0.0
# ...                               ...                  ...
# 88765                             NaN                  2.0
# 88786            UAS TRANSERVICES INC                  0.0
# 88804         YR-AIRCRAFT LEASING LLC                  0.0
# 88834      Creamer Pilot Services LLC                  0.0
# 88867  REACH AIR MEDICAL SERVICES LLC                  0.0
#
#       Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# 8                        0.0                  0.0             2.0
# 25                       0.0                  0.0             0.0
# 37                       0.0                  0.0             0.0
# 40                       0.0                  0.0             1.0
# 41                       1.0                  0.0             1.0
# ...                      ...                  ...             ...
# 88765                    0.0                  0.0             0.0
# 88786                    2.0                  0.0             1.0
# 88804                    0.0                  0.0             7.0
# 88834                    2.0                  0.0             6.0
# 88867                    1.0                  0.0             0.0
#
#       Weather.Condition  Broad.phase.of.flight   Report.Status  \
# 8                   IMC                Landing  Probable Cause
# 25                  IMC               Approach  Probable Cause
# 37                  IMC                 Cruise  Probable Cause
# 40                  VMC                 Cruise  Probable Cause
# 41                  VMC                Descent  Probable Cause
# ...                 ...                    ...             ...
# 88765               IMC                    NaN             NaN
# 88786               IMC                    NaN             NaN
# 88804               VMC                    NaN             NaN
# 88834               IMC                    NaN             NaN
# 88867               NaN                    NaN             NaN
#
#       Publication.Date
# 8           01-01-1982
# 25          03-01-1983
# 37          05-01-1983
# 40          05-01-1983
# 41          05-01-1983
# ...                ...
# 88765       18-11-2022
# 88786       09-12-2022
# 88804       19-12-2022
# 88834       14-12-2022
# 88867       27-12-2022
#
# [3843 rows x 31 columns]

# %% [markdown]
# Check for null values in the entire dataframe.
# Drop the 'not of much importance' to our analysis
# columns such as longitude, latitude, airport code/name, FAR description and schedule.
# Columns that does not directly impact the risk of an aircraft

# %%
#check for null in the entire dataframe
df.isna().sum()
# Out:
# Event.Id                     0
# Investigation.Type           0
# Accident.Number              0
# Event.Date                   0
# Location                     0
# Country                      0
# Latitude                  2969
# Longitude                 2969
# Airport.Code              1768
# Airport.Name              1607
# Injury.Severity              1
# Aircraft.damage             85
# Aircraft.Category         2959
# Registration.Number          1
# Make                         0
# Model                        1
# Amateur.Built                0
# Number.of.Engines           75
# Engine.Type                 99
# FAR.Description           2958
# Schedule                  3763
# Purpose.of.flight            0
# Air.carrier               3485
# Total.Fatal.Injuries       325
# Total.Serious.Injuries     389
# Total.Minor.Injuries       368
# Total.Uninjured            159
# Weather.Condition           21
# Broad.phase.of.flight      497
# Report.Status               81
# Publication.Date           986
# dtype: int64

# %%
#drop some columns, those not needed for our analysis
df.drop(columns = ['Airport.Name', 'Registration.Number', 'FAR.Description',
                  'Schedule', 'Air.carrier', 'Report.Status',  'Broad.phase.of.flight', 'Amateur.Built', 'Publication.Date'], inplace = True)

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 8      20020909X01561           Accident      NYC82DA015  1982-01-01
# 25     20020917X01905           Accident      DCA82AA008  1982-01-03
# 37     20020917X02304           Accident      LAX82FUM06  1982-01-05
# 40     20020917X01764           Incident      ATL82IA029  1982-01-05
# 41     20020917X01993           Accident      FTW82DA037  1982-01-05
# ...               ...                ...             ...         ...
# 88765  20221109106270           Accident      CEN23FA031  2022-11-09
# 88786  20221115106296           Accident      CEN23LA037  2022-11-15
# 88804  20221121106337           Accident      ANC23LA006  2022-11-20
# 88834  20221130106387           Accident      CEN23LA056  2022-11-29
# 88867  20221213106456           Accident      WPR23LA066  2022-12-12
#
#                Location        Country Latitude Longitude Airport.Code  \
# 8      EAST HANOVER, NJ  United States      NaN       NaN          N58
# 25          ASHLAND, VA  United States      NaN       NaN          NaN
# 37           RAMONA, CA  United States      NaN       NaN          L39
# 40        PENSACOLA, FL  United States      NaN       NaN          NaN
# 41           LONOKE, AR  United States      NaN       NaN          NaN
# ...                 ...            ...      ...       ...          ...
# 88765       Bignell, NE  United States  041453N  1003648W          LBF
# 88786      Pewaukee, WI  United States  043228N  0881413W          UES
# 88804        Bethel, AK  United States  604243N  1614111W          NaN
# 88834    Batesville, AR  United States  354334N  0913851W          BVX
# 88867       Redding, CA  United States  039101N  0121410W          RDD
#
#       Injury.Severity  ...                Make       Model Number.of.Engines  \
# 8           Non-Fatal  ...              Cessna        401B               2.0
# 25           Fatal(8)  ...              Cessna        414A               2.0
# 37           Fatal(3)  ...              Navion           A               1.0
# 40           Incident  ...            Rockwell         114               1.0
# 41          Non-Fatal  ...               Piper   PA-24-250               1.0
# ...               ...  ...                 ...         ...               ...
# 88765           Fatal  ...               PIPER  PA46-500TP               1.0
# 88786           Minor  ...           FAIRCHILD    SA227-AT               2.0
# 88804       Non-Fatal  ...              CESSNA         207               1.0
# 88834           Minor  ...         LEARJET INC          45               2.0
# 88867           Minor  ...  AIRBUS HELICOPTERS   EC 130 T2               1.0
#
#          Engine.Type  Purpose.of.flight Total.Fatal.Injuries  \
# 8      Reciprocating           Business                  0.0
# 25     Reciprocating           Business                  8.0
# 37     Reciprocating           Business                  3.0
# 40     Reciprocating           Business                  0.0
# 41     Reciprocating           Business                  0.0
# ...              ...                ...                  ...
# 88765            NaN           Business                  2.0
# 88786            NaN           Business                  0.0
# 88804            NaN           Business                  0.0
# 88834            NaN           Business                  0.0
# 88867            NaN           Business                  0.0
#
#       Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 8                        0.0                   0.0              2.0
# 25                       0.0                   0.0              0.0
# 37                       0.0                   0.0              0.0
# 40                       0.0                   0.0              1.0
# 41                       1.0                   0.0              1.0
# ...                      ...                   ...              ...
# 88765                    0.0                   0.0              0.0
# 88786                    2.0                   0.0              1.0
# 88804                    0.0                   0.0              7.0
# 88834                    2.0                   0.0              6.0
# 88867                    1.0                   0.0              0.0
#
#        Weather.Condition
# 8                    IMC
# 25                   IMC
# 37                   IMC
# 40                   VMC
# 41                   VMC
# ...                  ...
# 88765                IMC
# 88786                IMC
# 88804                VMC
# 88834                IMC
# 88867                NaN
#
# [3843 rows x 22 columns]

# %% [markdown]
# Now we are at the very surface of our scope. United States -- Business.
# The risk of an aircraft with the available data will first be determined by involvement in accident and incidents.
# we can look at accidents and incidents separately.

# %%
#Filter by accidents
df_Accidents = df[df['Investigation.Type'] == 'Accident'].copy()
df_Incidents = df[df['Investigation.Type'] == 'Incident'].copy()
df_Accidents.reset_index(drop = True, inplace = True)
df_Accidents
# Out:
#             Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0     20020909X01561           Accident      NYC82DA015  1982-01-01
# 1     20020917X01905           Accident      DCA82AA008  1982-01-03
# 2     20020917X02304           Accident      LAX82FUM06  1982-01-05
# 3     20020917X01993           Accident      FTW82DA037  1982-01-05
# 4     20020917X02157           Accident      LAX82DA039  1982-01-06
# ...              ...                ...             ...         ...
# 3739  20221109106270           Accident      CEN23FA031  2022-11-09
# 3740  20221115106296           Accident      CEN23LA037  2022-11-15
# 3741  20221121106337           Accident      ANC23LA006  2022-11-20
# 3742  20221130106387           Accident      CEN23LA056  2022-11-29
# 3743  20221213106456           Accident      WPR23LA066  2022-12-12
#
#                Location        Country Latitude Longitude Airport.Code  \
# 0      EAST HANOVER, NJ  United States      NaN       NaN          N58
# 1           ASHLAND, VA  United States      NaN       NaN          NaN
# 2            RAMONA, CA  United States      NaN       NaN          L39
# 3            LONOKE, AR  United States      NaN       NaN          NaN
# 4     MAMMOTH LAKES, CA  United States      NaN       NaN          MMH
# ...                 ...            ...      ...       ...          ...
# 3739        Bignell, NE  United States  041453N  1003648W          LBF
# 3740       Pewaukee, WI  United States  043228N  0881413W          UES
# 3741         Bethel, AK  United States  604243N  1614111W          NaN
# 3742     Batesville, AR  United States  354334N  0913851W          BVX
# 3743        Redding, CA  United States  039101N  0121410W          RDD
#
#      Injury.Severity  ...                Make       Model Number.of.Engines  \
# 0          Non-Fatal  ...              Cessna        401B               2.0
# 1           Fatal(8)  ...              Cessna        414A               2.0
# 2           Fatal(3)  ...              Navion           A               1.0
# 3          Non-Fatal  ...               Piper   PA-24-250               1.0
# 4          Non-Fatal  ...        Aerospatiale     SA-316B               1.0
# ...              ...  ...                 ...         ...               ...
# 3739           Fatal  ...               PIPER  PA46-500TP               1.0
# 3740           Minor  ...           FAIRCHILD    SA227-AT               2.0
# 3741       Non-Fatal  ...              CESSNA         207               1.0
# 3742           Minor  ...         LEARJET INC          45               2.0
# 3743           Minor  ...  AIRBUS HELICOPTERS   EC 130 T2               1.0
#
#         Engine.Type  Purpose.of.flight Total.Fatal.Injuries  \
# 0     Reciprocating           Business                  0.0
# 1     Reciprocating           Business                  8.0
# 2     Reciprocating           Business                  3.0
# 3     Reciprocating           Business                  0.0
# 4       Turbo Shaft           Business                  0.0
# ...             ...                ...                  ...
# 3739            NaN           Business                  2.0
# 3740            NaN           Business                  0.0
# 3741            NaN           Business                  0.0
# 3742            NaN           Business                  0.0
# 3743            NaN           Business                  0.0
#
#      Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 0                       0.0                   0.0              2.0
# 1                       0.0                   0.0              0.0
# 2                       0.0                   0.0              0.0
# 3                       1.0                   0.0              1.0
# 4                       0.0                   0.0              6.0
# ...                     ...                   ...              ...
# 3739                    0.0                   0.0              0.0
# 3740                    2.0                   0.0              1.0
# 3741                    0.0                   0.0              7.0
# 3742                    2.0                   0.0              6.0
# 3743                    1.0                   0.0              0.0
#
#       Weather.Condition
# 0                   IMC
# 1                   IMC
# 2                   IMC
# 3                   VMC
# 4                   VMC
# ...                 ...
# 3739                IMC
# 3740                IMC
# 3741                VMC
# 3742                IMC
# 3743                NaN
#
# [3744 rows x 22 columns]

# %% [markdown]
# At this point, we have dataframe, df_Accidents, for countries = USA, purpose = Business and investigation type for accidents and incidents, separately.
# Next we look at the types of aircrafts in the df_Accidents dataframe.
# Check for null values in the new data frame.

# %%
df_Accidents.info() # The non-Null count shows that we have missing data in most columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3744 entries, 0 to 3743
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                3744 non-null   object
#  1   Investigation.Type      3744 non-null   object
#  2   Accident.Number         3744 non-null   object
#  3   Event.Date              3744 non-null   object
#  4   Location                3744 non-null   object
#  5   Country                 3744 non-null   object
#  6   Latitude                845 non-null    object
#  7   Longitude               845 non-null    object
#  8   Airport.Code            2008 non-null   object
#  9   Injury.Severity         3743 non-null   object
#  10  Aircraft.damage         3689 non-null   object
#  11  Aircraft.Category       858 non-null    object
#  12  Make                    3744 non-null   object
#  13  Model                   3743 non-null   object
#  14  Number.of.Engines       3673 non-null   float64
#  15  Engine.Type             3649 non-null   object
#  16  Purpose.of.flight       3744 non-null   object
#  17  Total.Fatal.Injuries    3434 non-null   float64
#  18  Total.Serious.Injuries  3370 non-null   float64
#  19  Total.Minor.Injuries    3391 non-null   float64
#  20  Total.Uninjured         3585 non-null   float64
#  21  Weather.Condition       3724 non-null   object
# dtypes: float64(5), object(17)
# memory usage: 643.6+ KB

# %%
#Check for the nulls
df_Accidents.isna().sum()
# Out:
# Event.Id                     0
# Investigation.Type           0
# Accident.Number              0
# Event.Date                   0
# Location                     0
# Country                      0
# Latitude                  2899
# Longitude                 2899
# Airport.Code              1736
# Injury.Severity              1
# Aircraft.damage             55
# Aircraft.Category         2886
# Make                         0
# Model                        1
# Number.of.Engines           71
# Engine.Type                 95
# Purpose.of.flight            0
# Total.Fatal.Injuries       310
# Total.Serious.Injuries     374
# Total.Minor.Injuries       353
# Total.Uninjured            159
# Weather.Condition           20
# dtype: int64

# %%
# For categorical missing rows, fill in with the mode of that column
mode = df_Accidents['Injury.Severity'].mode()[0]
mode
# Out:
# 'Non-Fatal'

# %%
# Fill in the null values with the mode
df_Accidents['Injury.Severity'] = df_Accidents['Injury.Severity'].fillna(mode)

# %%
#Check for the null after filling
df_Accidents['Injury.Severity'].isna().sum()
# Out:
# 0

# %%
#use mode to fill
mode = df_Accidents['Aircraft.damage'].mode()[0]
df_Accidents['Aircraft.damage'] = df_Accidents['Aircraft.damage'].fillna(mode)

# %%
#Use the mode to fill
mode = df_Accidents['Model'].mode()[0]
df_Accidents['Model'] = df_Accidents['Model'].fillna(mode)

# %%
#Fill in the nulls in Number.of.Engines with mode 
mode_4 = df_Accidents ['Number.of.Engines'].mode()[0]
df_Accidents ['Number.of.Engines'] = df_Accidents ['Number.of.Engines'].fillna(mode_4)

# %%
#get the mode of the Engine.Type column
mode = df_Accidents ['Engine.Type'].mode()[0]
#fill the null with the mode
df_Accidents ['Engine.Type'] = df_Accidents ['Engine.Type'].fillna(mode)
#Check for null
df_Accidents['Engine.Type'].isna().sum()
# Out:
# 0

# %%
df_Accidents.isna().sum()
# Out:
# Event.Id                     0
# Investigation.Type           0
# Accident.Number              0
# Event.Date                   0
# Location                     0
# Country                      0
# Latitude                  2899
# Longitude                 2899
# Airport.Code              1736
# Injury.Severity              0
# Aircraft.damage              0
# Aircraft.Category         2886
# Make                         0
# Model                        0
# Number.of.Engines            0
# Engine.Type                  0
# Purpose.of.flight            0
# Total.Fatal.Injuries       310
# Total.Serious.Injuries     374
# Total.Minor.Injuries       353
# Total.Uninjured            159
# Weather.Condition           20
# dtype: int64

# %% [markdown]
# Find the data types of the numerical columns.
# Replace the NaN with the mean of the columns.

# %%
# Check for the data types
print([df_Accidents['Total.Fatal.Injuries'].dtype])
print([df_Accidents['Total.Serious.Injuries'].dtype])
print([df_Accidents['Total.Minor.Injuries'].dtype])
print([df_Accidents['Total.Uninjured'].dtype])
# Out:
# [dtype('float64')]
# [dtype('float64')]
# [dtype('float64')]
# [dtype('float64')]

# %%
# Get the aggregate means
mean = df_Accidents['Total.Fatal.Injuries'].mean()
mean_1 = df_Accidents['Total.Serious.Injuries'].mean()
mean_2 = df_Accidents['Total.Minor.Injuries'].mean()
mean_3 = df_Accidents['Total.Uninjured'].mean()

# %%
# Fill in the mean for the numerical columns with nulls
df_Accidents['Total.Fatal.Injuries'] = df_Accidents['Total.Fatal.Injuries'].fillna(mean)
df_Accidents['Total.Serious.Injuries'] = df_Accidents['Total.Serious.Injuries'].fillna(mean_1)
df_Accidents['Total.Minor.Injuries'] = df_Accidents['Total.Minor.Injuries'].fillna(mean_2)
df_Accidents['Total.Uninjured'] = df_Accidents['Total.Uninjured'].fillna(mean_3)

# %%
#Check for the nulls
df_Accidents.isna().sum()
# Out:
# Event.Id                     0
# Investigation.Type           0
# Accident.Number              0
# Event.Date                   0
# Location                     0
# Country                      0
# Latitude                  2899
# Longitude                 2899
# Airport.Code              1736
# Injury.Severity              0
# Aircraft.damage              0
# Aircraft.Category         2886
# Make                         0
# Model                        0
# Number.of.Engines            0
# Engine.Type                  0
# Purpose.of.flight            0
# Total.Fatal.Injuries         0
# Total.Serious.Injuries       0
# Total.Minor.Injuries         0
# Total.Uninjured              0
# Weather.Condition           20
# dtype: int64

# %%
#Value counts
df_Accidents['Aircraft.Category'].value_counts()
# Out:
# Airplane      719
# Helicopter    109
# Balloon        27
# Glider          2
# Gyrocraft       1
# Name: Aircraft.Category, dtype: int64

# %%
# confirm
df_Accidents['Aircraft.Category'].isna().value_counts()
# Out:
# True     2886
# False     858
# Name: Aircraft.Category, dtype: int64

# %% [markdown]
# By checking for the counts of null values, most of the aircraft category elements are missing.
# Considerations: This is a categorical data and imputing with the mode of that column would suffice.
# However, imputing at this level would result to analytical erros for two reasons
# 1. the missing data is much more than the avail data and
# 2. Each aircraft category, generally has its sub-categories, ie the make of the aircraft. As per the data, the category could be missing but the sub-category, ie, the make of the aircraft is provided.
# Thus replace the NaN in the category column with 'mode'.
# Now we have all the data cleaned and ready for analysis.

# %%
# Compute the mode
mode = df_Accidents['Aircraft.Category'].mode()[0]
mode
# fill in
df_Accidents['Aircraft.Category'] = df_Accidents['Aircraft.Category'].fillna(mode)
df_Accidents['Aircraft.Category'].isna().sum()
df_Accidents['Aircraft.Category'].value_counts()
# Out:
# Airplane      3605
# Helicopter     109
# Balloon         27
# Glider           2
# Gyrocraft        1
# Name: Aircraft.Category, dtype: int64

# %%
# Check the shape
df_Accidents.shape
# Out:
# (3744, 22)

# %%
# set all elements in the 'Make' column as lower case
df_Accidents['Make'] = df_Accidents['Make'].str.lower()
df_Accidents['Make'].value_counts().head(10)
# Out:
# cessna          1278
# piper            773
# beech            460
# bell             145
# mooney            95
# hughes            77
# bellanca          56
# robinson          55
# de havilland      38
# maule             30
# Name: Make, dtype: int64

# %%
# Create replacement list for the above
replacements = {
    'cessna': 'Cessna',
    'piper': 'Piper',
    'beech': 'Beech',
    'other notables': 'Other Notables',
    'robinson': 'Robinson',
    'robinson helicopter company': 'Robinson',
    'cirrus design corp': 'Cirrus',
    'bell': 'Bell',
    'cameron balloons': 'Cameron Balloons',
    'bell helicopter': 'Bell',
    'robinson helicopter': 'Robinson',
    'dehavilland': 'De Havilland',
    'mooney': 'Mooney',
    'raytheon': 'Raytheon',
    'cirrus': 'Cirrus',
    'aero commander': 'Aero Commander',
    'douglas': 'Douglas',
    'hughes': 'Hughes',
    'raytheon aircraft company': 'Raytheon',
    'enstrom': 'Enstrom',
    'eurocopter': 'Eurocopter',
    'grumman': 'Grumman',
    'air tractor': 'Air Tractor',
    'socata': 'Socata',
    'de havilland': 'De Havilland',
    'canadair': 'Canadair',
    'maule': 'Maule',
    'swearingen': 'Swearingen',
    'bellanca': 'Bellanca',
    'gulfstream': 'Gulfstream',
    'lancair': 'Lancair',
    'lindstrand': 'Lindstrand',
    'aerospatiale': 'Aerospatiale',
    'rockwell': 'Rockwell',
    'piaggio': 'Piaggio',
    'flight design': 'Flight Design',
    'dassault falcon': 'Dassault Falcon',
    'learjet inc': 'Learjet',
    'head': 'Head',
    'champion': 'Champion',
    'aerospace & defense': 'Aerospace & Defense',
    'stinson': 'Stinson',
    'north american': 'North American',
    'smith': 'Smith',
    'cirrus design corp.': 'Cirrus',
    'mooney airplane co inc': 'Mooney',
    'hiller': 'Hiller',
    'new piper aircraft inc': 'New Piper Aircraft Inc',
    'embraer': 'Embraer',
    'sikorsky': 'Sikorsky',
    'curtiss wright': 'Curtiss Wright',
    'textron aviation': 'Textron Aviation',
    'evolution 19': 'Evolution 19',
    'icon': 'Icon',
    'boyd bruce': 'Boyd Bruce',
    'israel aircraft industries': 'Israel Aircraft Industries',
    'balony kubicek spol': 'Balony Kubicek Spol',
    'ludwig larry e': 'Ludwig Larry E',
    'bell helicopter textron canada': 'Bell Helicopter Textron Canada',
    'hawker beechcraft corporation': 'Hawker Beechcraft Corporation',
    'schoepflin': 'Schoepflin',
    'northrop': 'Northrop',
    'boeing': 'Boeing',
    'mitsubishi': 'Mitsubishi',
    'navion': 'Navion',
    'ultramagic': 'Ultramagic',
    'ultramagic sa': 'Ultramagic SA',
    'learjet': 'Learjet',
    'balony kubicek spol sro': 'Balony Kubicek Spol SRO',
    'bristell': 'Bristell',
    'mkii corporation': 'MKII Corporation',
    'gulfstream am corp comm div': 'Gulfstream AM Corp Comm Div',
    'northland aviation llc': 'Northland Aviation LLC',
    'diamond aircraft ind inc': 'Diamond Aircraft Ind Inc',
    'fairchild': 'Fairchild',
    'kubicek': 'Kubicek',
    'jackson': 'Jackson',
    'bombardier': 'Bombardier',
    'pridmore': 'Pridmore',
    'fairchild merlin': 'Fairchild Merlin',
    'aerostar international': 'Aerostar International',
    'let': 'LET',
    'taylorcraft aviation': 'Taylorcraft Aviation',
    'thrush': 'Thrush',
    'piper aircraft corporation': 'Piper Aircraft Corporation',
    'rogerson hiller corp.': 'Rogerson Hiller Corp.',
    'pilatus': 'Pilatus',
    'classic aircraft': 'Classic Aircraft',
    'beechcraft': 'Beech',
    'great lakes': 'Great Lakes',
    'rice leo b': 'Rice Leo B',
    'grumman aircraft eng corp': 'Grumman Aircraft Eng Corp',
    'forbes': 'Forbes',
    'lciv llc': 'Lciv LLC',
    'aero vodochody': 'Aero Vodochody',
    'bereznak': 'Bereznak',
    'eads socata': 'EADS Socata',
    'siai marchetti': 'SIAI Marchetti'
}

# %%
# Replacement of same 'Make' names
df_Accidents['Make'] = df_Accidents['Make'].replace(replacements)

df_Accidents['Make'].value_counts()
# Out:
# Cessna                        1278
# Piper                          773
# Beech                          461
# Bell                           146
# Mooney                          97
#                               ...
# commander                        1
# birx                             1
# Piper Aircraft Corporation       1
# lindstrand balloons              1
# american eurocopter              1
# Name: Make, Length: 241, dtype: int64

# %%
#Check for duplicates
duplicates = df_Accidents[df_Accidents.duplicated()]
duplicates
# Out:
#             Event.Id Investigation.Type Accident.Number  Event.Date  \
# 3727  20220822105776           Accident      ERA22LA379  2022-08-20
#
#           Location        Country Latitude Longitude Airport.Code  \
# 3727  Bealeton, VA  United States  038338N  0774255W         3VA3
#
#      Injury.Severity  ...    Make  Model Number.of.Engines    Engine.Type  \
# 3727           Minor  ...  Boeing  A75N1               1.0  Reciprocating
#
#       Purpose.of.flight Total.Fatal.Injuries Total.Serious.Injuries  \
# 3727           Business                  0.0                    2.0
#
#       Total.Minor.Injuries  Total.Uninjured  Weather.Condition
# 3727                   0.0              2.0                VMC
#
# [1 rows x 22 columns]

# %%
#Drop the duplicates
df_Accidents = df_Accidents.drop_duplicates().copy()
df_Accidents.shape
# Out:
# (3743, 22)

# %%
 #change the data from string to datetime
# first confirm the datatype
print(df_Accidents['Event.Date'].dtype )  
# Convert the event.date from objects to dates
df_Accidents['Event.Date'] = pd.to_datetime(df_Accidents['Event.Date'], format = '%Y-%m-%d')
# confirm the type of df_Accidents['Event.Date']
df_Accidents['Event.Date'].dtype
# Out:
# object
# dtype('<M8[ns]')

# %%
df_Accidents.shape
# Out:
# (3743, 22)

# %% [markdown]
# Due to technological advancement, considering airplane accidents as far back in the 1900 would
# not serve our analysis, or it could in minimal measures.
# The current technology is far more advanced and thus I only consider the data dating back to
# 2005.

# %%
# filter the data frame for the year 2005 to present
# first create a filter function
filt = (df_Accidents['Event.Date'] >= '2005')
df_Accidents = df_Accidents.loc[filt]
df_Accidents
# Out:
#             Event.Id Investigation.Type Accident.Number Event.Date  \
# 3114  20050124X00093           Accident      NYC05LA044 2005-01-04
# 3115  20050127X00110           Accident      CHI05CA051 2005-01-09
# 3116  20050127X00112           Accident      SEA05CA033 2005-01-10
# 3117  20050118X00063           Accident      ATL05FA043 2005-01-10
# 3118  20050211X00175           Accident      DEN05CA050 2005-01-19
# ...              ...                ...             ...        ...
# 3739  20221109106270           Accident      CEN23FA031 2022-11-09
# 3740  20221115106296           Accident      CEN23LA037 2022-11-15
# 3741  20221121106337           Accident      ANC23LA006 2022-11-20
# 3742  20221130106387           Accident      CEN23LA056 2022-11-29
# 3743  20221213106456           Accident      WPR23LA066 2022-12-12
#
#                 Location        Country   Latitude    Longitude Airport.Code  \
# 3114       CLEVELAND, OH  United States     41.565   -81.486111          CGF
# 3115  HARBOR SPRINGS, MI  United States  45.425556   -84.913333          MGN
# 3116        BILLINGS, MT  United States  45.808611  -108.530834          BIL
# 3117      CHARLESTON, SC  United States  32.895277   -80.040555          CHS
# 3118           LOGAN, UT  United States  41.788333  -111.853333          LGU
# ...                  ...            ...        ...          ...          ...
# 3739         Bignell, NE  United States    041453N     1003648W          LBF
# 3740        Pewaukee, WI  United States    043228N     0881413W          UES
# 3741          Bethel, AK  United States    604243N     1614111W          NaN
# 3742      Batesville, AR  United States    354334N     0913851W          BVX
# 3743         Redding, CA  United States    039101N     0121410W          RDD
#
#      Injury.Severity  ...                Make       Model Number.of.Engines  \
# 3114       Non-Fatal  ...      Aero Commander        690A               2.0
# 3115       Non-Fatal  ...              Cessna        414A               2.0
# 3116       Non-Fatal  ...              Cessna         180               1.0
# 3117        Fatal(1)  ...               Piper       PA-30               2.0
# 3118       Non-Fatal  ...             Grumman      G-1159               2.0
# ...              ...  ...                 ...         ...               ...
# 3739           Fatal  ...               Piper  PA46-500TP               1.0
# 3740           Minor  ...           Fairchild    SA227-AT               2.0
# 3741       Non-Fatal  ...              Cessna         207               1.0
# 3742           Minor  ...             Learjet          45               2.0
# 3743           Minor  ...  airbus helicopters   EC 130 T2               1.0
#
#         Engine.Type  Purpose.of.flight Total.Fatal.Injuries  \
# 3114     Turbo Prop           Business             0.583867
# 3115  Reciprocating           Business             0.583867
# 3116  Reciprocating           Business             0.583867
# 3117  Reciprocating           Business             1.000000
# 3118      Turbo Jet           Business             0.583867
# ...             ...                ...                  ...
# 3739  Reciprocating           Business             2.000000
# 3740  Reciprocating           Business             0.000000
# 3741  Reciprocating           Business             0.000000
# 3742  Reciprocating           Business             0.000000
# 3743  Reciprocating           Business             0.000000
#
#      Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 3114                0.24362              0.309643         3.000000
# 3115                0.24362              0.309643         5.000000
# 3116                0.24362              0.309643         1.000000
# 3117                0.24362              0.309643         1.388563
# 3118                0.24362              0.309643         9.000000
# ...                     ...                   ...              ...
# 3739                0.00000              0.000000         0.000000
# 3740                2.00000              0.000000         1.000000
# 3741                0.00000              0.000000         7.000000
# 3742                2.00000              0.000000         6.000000
# 3743                1.00000              0.000000         0.000000
#
#       Weather.Condition
# 3114                VMC
# 3115                VMC
# 3116                VMC
# 3117                VMC
# 3118                IMC
# ...                 ...
# 3739                IMC
# 3740                IMC
# 3741                VMC
# 3742                IMC
# 3743                NaN
#
# [629 rows x 22 columns]

# %%
# Cofirm the shape
df_Accidents.shape
# Out:
# (629, 22)

# %%
df_Accidents.to_excel('df_Accidents_Final.xlsx', index = False)

# %%
# Value counts
df_Accidents['Make'].value_counts().head(10)
# Out:
# Cessna          165
# Piper            84
# Beech            73
# Robinson         43
# Bell             22
# Cirrus           20
# De Havilland     13
# Raytheon         12
# Mooney           10
# Hughes            6
# Name: Make, dtype: int64

# %%
# Value counts of Aircraft.Category
df_Accidents['Aircraft.Category'].value_counts()
# Out:
# Airplane      519
# Helicopter     83
# Balloon        24
# Glider          2
# Gyrocraft       1
# Name: Aircraft.Category, dtype: int64

# %% [markdown]
# Draw a bar graph for the 'aircraft.Category' column

# %%
# Again draw a graph for the data frane 2005- present
y = df_Accidents['Aircraft.Category'].value_counts().values.tolist()
x = df_Accidents['Aircraft.Category'].value_counts().index.tolist()

# Plot the bar graph
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize = (8,6))
ax.bar(x, y, label = 'Categories', log = True);

ax.set_title('Accidents from 2005 - 2022')
ax.set_xlabel('Aircraft Category')
ax.set_ylabel('counts(no. of accidents)')

plt.legend()

plt.tight_layout()

plt.show();

# %% [markdown]
# The bar graph shows the number of counts of accidents for each category over the period. The Airplane category has the most counts.
# At this point, we'd be quick to prefer the helicopter or other categories as the least risk venture, but each category shows different number of aircrafts, in that category, that have had accidents.
# Each category have subcategories differentiated by the make and the model, go further into each sub-category.
# check for the trends of accidents over that time period

# %%
# Create a column 'Year' and append to the df_Accidents dataframe
df_Accidents['Year'] = (df_Accidents['Event.Date'].dt.year).copy()
df_Accidents.reset_index(drop=True)
# Out:
#            Event.Id Investigation.Type Accident.Number Event.Date  \
# 0    20050124X00093           Accident      NYC05LA044 2005-01-04
# 1    20050127X00110           Accident      CHI05CA051 2005-01-09
# 2    20050127X00112           Accident      SEA05CA033 2005-01-10
# 3    20050118X00063           Accident      ATL05FA043 2005-01-10
# 4    20050211X00175           Accident      DEN05CA050 2005-01-19
# ..              ...                ...             ...        ...
# 624  20221109106270           Accident      CEN23FA031 2022-11-09
# 625  20221115106296           Accident      CEN23LA037 2022-11-15
# 626  20221121106337           Accident      ANC23LA006 2022-11-20
# 627  20221130106387           Accident      CEN23LA056 2022-11-29
# 628  20221213106456           Accident      WPR23LA066 2022-12-12
#
#                Location        Country   Latitude    Longitude Airport.Code  \
# 0         CLEVELAND, OH  United States     41.565   -81.486111          CGF
# 1    HARBOR SPRINGS, MI  United States  45.425556   -84.913333          MGN
# 2          BILLINGS, MT  United States  45.808611  -108.530834          BIL
# 3        CHARLESTON, SC  United States  32.895277   -80.040555          CHS
# 4             LOGAN, UT  United States  41.788333  -111.853333          LGU
# ..                  ...            ...        ...          ...          ...
# 624         Bignell, NE  United States    041453N     1003648W          LBF
# 625        Pewaukee, WI  United States    043228N     0881413W          UES
# 626          Bethel, AK  United States    604243N     1614111W          NaN
# 627      Batesville, AR  United States    354334N     0913851W          BVX
# 628         Redding, CA  United States    039101N     0121410W          RDD
#
#     Injury.Severity  ...       Model Number.of.Engines    Engine.Type  \
# 0         Non-Fatal  ...        690A               2.0     Turbo Prop
# 1         Non-Fatal  ...        414A               2.0  Reciprocating
# 2         Non-Fatal  ...         180               1.0  Reciprocating
# 3          Fatal(1)  ...       PA-30               2.0  Reciprocating
# 4         Non-Fatal  ...      G-1159               2.0      Turbo Jet
# ..              ...  ...         ...               ...            ...
# 624           Fatal  ...  PA46-500TP               1.0  Reciprocating
# 625           Minor  ...    SA227-AT               2.0  Reciprocating
# 626       Non-Fatal  ...         207               1.0  Reciprocating
# 627           Minor  ...          45               2.0  Reciprocating
# 628           Minor  ...   EC 130 T2               1.0  Reciprocating
#
#     Purpose.of.flight  Total.Fatal.Injuries Total.Serious.Injuries  \
# 0            Business              0.583867                0.24362
# 1            Business              0.583867                0.24362
# 2            Business              0.583867                0.24362
# 3            Business              1.000000                0.24362
# 4            Business              0.583867                0.24362
# ..                ...                   ...                    ...
# 624          Business              2.000000                0.00000
# 625          Business              0.000000                2.00000
# 626          Business              0.000000                0.00000
# 627          Business              0.000000                2.00000
# 628          Business              0.000000                1.00000
#
#     Total.Minor.Injuries  Total.Uninjured  Weather.Condition  Year
# 0               0.309643         3.000000                VMC  2005
# 1               0.309643         5.000000                VMC  2005
# 2               0.309643         1.000000                VMC  2005
# 3               0.309643         1.388563                VMC  2005
# 4               0.309643         9.000000                IMC  2005
# ..                   ...              ...                ...   ...
# 624             0.000000         0.000000                IMC  2022
# 625             0.000000         1.000000                IMC  2022
# 626             0.000000         7.000000                VMC  2022
# 627             0.000000         6.000000                IMC  2022
# 628             0.000000         0.000000                NaN  2022
#
# [629 rows x 23 columns]

# %%
# First group by category and years and see the trend over the years
Grouped_category_years = df_Accidents.groupby(['Year', 'Aircraft.Category'])
counts = Grouped_category_years.size()

Group_df = counts.reset_index(name= 'counts') # create a new data frame
Group_df.head()
# Out:
#    Year Aircraft.Category  counts
# 0  2005          Airplane      51
# 1  2005           Balloon       1
# 2  2005        Helicopter       4
# 3  2006          Airplane      41
# 4  2006        Helicopter       6

# %%
# Now plot to show the trend 
# Import seaborn and matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# set the size to plot on
plt.figure(figsize=(10,8))
# create the plot using searbon and customize
sns.lineplot(data=Group_df, 
             x='Year', 
             y='counts', 
             hue='Aircraft.Category', 
             linewidth=2.5, 
             marker='X',
             palette='Set1'
           )
# Add plot title, customize with fontsizes and color 
plt.title('Trend of Aircraft Accidents by Category (2005 - Present)', 
          fontsize=16, 
          fontweight='bold', 
          color='darkblue')
# label the axes accordingly
plt.xlabel('Year', fontsize=14, fontweight='bold')
plt.ylabel('Number of Accidents', fontsize=14, fontweight='bold')
# Add grid lines
plt.grid(visible=True, linestyle='--', linewidth=0.7, alpha=0.7)
# Include the legend
plt.legend(title='Aircraft Category', loc='upper right', fontsize=8)

# %% [markdown]
# From the above line plots, it is evident that over the time the airplane category have had more accidents than
# the other categories; balloon, helicopter and glider.
# The helicopter category have more accidents than the balloon.
# In the recent years, the trend of accidents
# have increased for the airplanes and is reducing for the balloon and helicopter category. However, the level of scope at
# aircraft category does not inform our decision to ditch airplanes for analysis since each category is composed of subcategory aircrafts.
# we can further delve into specific sub-categories and do more analysis.

# %% [markdown]
# Group the df_Accidents dataframe by aircraft category.Get each category and cross check to see the 'Make' column.

# %%
# Access each category by grouping the data by aircraft category.
df_Accidents_Categories = df_Accidents.groupby(['Aircraft.Category'])
counts = df_Accidents_Categories.size()
# reset the index of the dataframe, # create a new data frame
Groups_df = counts.reset_index(name= 'counts') 
Groups_df.head()
# Out:
#   Aircraft.Category  counts
# 0          Airplane     519
# 1           Balloon      24
# 2            Glider       2
# 3         Gyrocraft       1
# 4        Helicopter      83

# %%
# We can now access each category individually.
# Use the .get_group() method and access each category separately
df_Airplanes = df_Accidents_Categories.get_group('Airplane').copy()
df_Airplanes.reset_index(drop= True)
# Out:
#            Event.Id Investigation.Type Accident.Number Event.Date  \
# 0    20050124X00093           Accident      NYC05LA044 2005-01-04
# 1    20050127X00110           Accident      CHI05CA051 2005-01-09
# 2    20050127X00112           Accident      SEA05CA033 2005-01-10
# 3    20050118X00063           Accident      ATL05FA043 2005-01-10
# 4    20050211X00175           Accident      DEN05CA050 2005-01-19
# ..              ...                ...             ...        ...
# 514  20221108106258           Accident      ERA23LA050 2022-11-05
# 515  20221109106270           Accident      CEN23FA031 2022-11-09
# 516  20221115106296           Accident      CEN23LA037 2022-11-15
# 517  20221121106337           Accident      ANC23LA006 2022-11-20
# 518  20221130106387           Accident      CEN23LA056 2022-11-29
#
#                Location        Country   Latitude    Longitude Airport.Code  \
# 0         CLEVELAND, OH  United States     41.565   -81.486111          CGF
# 1    HARBOR SPRINGS, MI  United States  45.425556   -84.913333          MGN
# 2          BILLINGS, MT  United States  45.808611  -108.530834          BIL
# 3        CHARLESTON, SC  United States  32.895277   -80.040555          CHS
# 4             LOGAN, UT  United States  41.788333  -111.853333          LGU
# ..                  ...            ...        ...          ...          ...
# 514     Farmingdale, NY  United States    404417N     0732334W          FRG
# 515         Bignell, NE  United States    041453N     1003648W          LBF
# 516        Pewaukee, WI  United States    043228N     0881413W          UES
# 517          Bethel, AK  United States    604243N     1614111W          NaN
# 518      Batesville, AR  United States    354334N     0913851W          BVX
#
#     Injury.Severity  ...       Model Number.of.Engines    Engine.Type  \
# 0         Non-Fatal  ...        690A               2.0     Turbo Prop
# 1         Non-Fatal  ...        414A               2.0  Reciprocating
# 2         Non-Fatal  ...         180               1.0  Reciprocating
# 3          Fatal(1)  ...       PA-30               2.0  Reciprocating
# 4         Non-Fatal  ...      G-1159               2.0      Turbo Jet
# ..              ...  ...         ...               ...            ...
# 514           Minor  ...        B-60               2.0  Reciprocating
# 515           Fatal  ...  PA46-500TP               1.0  Reciprocating
# 516           Minor  ...    SA227-AT               2.0  Reciprocating
# 517       Non-Fatal  ...         207               1.0  Reciprocating
# 518           Minor  ...          45               2.0  Reciprocating
#
#     Purpose.of.flight  Total.Fatal.Injuries Total.Serious.Injuries  \
# 0            Business              0.583867                0.24362
# 1            Business              0.583867                0.24362
# 2            Business              0.583867                0.24362
# 3            Business              1.000000                0.24362
# 4            Business              0.583867                0.24362
# ..                ...                   ...                    ...
# 514          Business              0.000000                2.00000
# 515          Business              2.000000                0.00000
# 516          Business              0.000000                2.00000
# 517          Business              0.000000                0.00000
# 518          Business              0.000000                2.00000
#
#     Total.Minor.Injuries  Total.Uninjured  Weather.Condition  Year
# 0               0.309643         3.000000                VMC  2005
# 1               0.309643         5.000000                VMC  2005
# 2               0.309643         1.000000                VMC  2005
# 3               0.309643         1.388563                VMC  2005
# 4               0.309643         9.000000                IMC  2005
# ..                   ...              ...                ...   ...
# 514             0.000000         0.000000                VMC  2022
# 515             0.000000         0.000000                IMC  2022
# 516             0.000000         1.000000                IMC  2022
# 517             0.000000         7.000000                VMC  2022
# 518             0.000000         6.000000                IMC  2022
#
# [519 rows x 23 columns]

# %%
# Get the shape of the dataframe
df_Airplanes.shape
# Out:
# (519, 23)

# %% [markdown]
# The analysis context is 'get the less risky aircrafts,' thus in this time frame, 2005 - 2022, from the each category,
# we pick the aircrafts that have had the least number of accidents, then do further analysis in regards
# to the number of injuries, fatalities, and the rest. By value counts method, we get to see a rough estimate of those with least number of accidents

# %%
# Get the least value counts
df_Airplanes['Make'].value_counts().tail(20)
# Out:
# Fairchild Merlin                  1
# smith, ted aerostar               1
# dassault-breguet                  1
# american champion (acac)          1
# Lciv LLC                          1
# embraer executive aircraft inc    1
# Diamond Aircraft Ind Inc          1
# Bristell                          1
# vans aircraft inc                 1
# siai-marchetti                    1
# morane-saulnier                   1
# Navion                            1
# eurocopter deutschland            1
# Fairchild                         1
# Forbes                            1
# air tractor inc                   1
# rockwell international            1
# piaggio aero industries s.p.a.    1
# Bereznak                          1
# britten-norman                    1
# Name: Make, dtype: int64

# %%
# Extract a dataframe from the df_Airplanes, that have had only 1 & 2 value counts
Counts = df_Airplanes['Make'].value_counts()
# Set the limit
limit = 2
# Get the  categories less than the limits
limited_Airplanes =Counts[Counts <= limit].index
# filter the df_Airplanes category
df_Airplanes_limited = df_Airplanes[df_Airplanes['Make'].isin(limited_Airplanes)]
df_Airplanes_limited.shape
# Out:
# (90, 23)

# %%
# for the new dataframe above, check the total fatalities column
#Check for the value counts of the 
df_Airplanes_limited ['Total.Fatal.Injuries'].value_counts()
# Plot the graphs
# Out:
# 0.000000    57
# 0.583867    15
# 2.000000     8
# 1.000000     7
# 3.000000     2
# 4.000000     1
# Name: Total.Fatal.Injuries, dtype: int64

# %% [markdown]
# Now extract the dataframe from the above that have the lowest number of Total.Fatal.Injuries, lowest Total.Serious.Injuries, lowest Total.Minor.Injuries and highest Total.Uninjured. By merging the dataframes, we get a a single dataframe that comprises
# only the safest/ the least risky aircraft in the airplane category.
# If the stakeholder is only interested in Airplane, this is the dataframe to be considered.

# %%
df_Least_fatalities = df_Airplanes_limited[df_Airplanes_limited['Total.Fatal.Injuries'] < 1]
df_Least_fatalities.reset_index(drop= True)
# Out:
#           Event.Id Investigation.Type Accident.Number Event.Date  \
# 0   20050211X00175           Accident      DEN05CA050 2005-01-19
# 1   20050510X00586           Accident      DFW05LA117 2005-05-09
# 2   20050701X00917           Accident      DEN05LA102 2005-06-29
# 3   20050816X01251           Accident      DEN05LA123 2005-08-07
# 4   20050831X01342           Accident      IAD05LA122 2005-08-12
# ..             ...                ...             ...        ...
# 67  20220726105587           Accident      WPR22LA272 2022-07-13
# 68  20220804105665           Accident      WPR22LA290 2022-08-03
# 69  20220822105776           Accident      ERA22LA379 2022-08-20
# 70  20221004106055           Accident      CEN23LA003 2022-10-03
# 71  20221115106296           Accident      CEN23LA037 2022-11-15
#
#            Location        Country   Latitude    Longitude Airport.Code  \
# 0         LOGAN, UT  United States  41.788333  -111.853333          LGU
# 1     BROWNWOOD, TX  United States  31.793611   -98.956389          BWD
# 2      SCOFIELD, UT  United States        NaN          NaN          NaN
# 3   ALBUQUERQUE, NM  United States  35.403611  -106.615278          ABQ
# 4    SAULSVILLE, WV  United States  37.652222       -81.45          NaN
# ..              ...            ...        ...          ...          ...
# 67    Scappoose, WA  United States    454616N     1225143W          SPB
# 68     Carlsbad, NM  United States    032201N     1041541W          CNM
# 69     Bealeton, VA  United States    038338N     0774255W         3VA3
# 70      Houston, TX  United States    293844N     0951642W          HOU
# 71     Pewaukee, WI  United States    043228N     0881413W          UES
#
#    Injury.Severity  ...           Model Number.of.Engines    Engine.Type  \
# 0        Non-Fatal  ...          G-1159               2.0      Turbo Jet
# 1        Non-Fatal  ...       NA-265-80               2.0      Turbo Fan
# 2        Non-Fatal  ...            480B               1.0     Turbo Prop
# 3        Non-Fatal  ...  Rutan Long EZE               1.0  Reciprocating
# 4        Non-Fatal  ...            280C               1.0  Reciprocating
# ..             ...  ...             ...               ...            ...
# 67       Non-Fatal  ...      PA-60-601P               2.0  Reciprocating
# 68       Non-Fatal  ...         TBM 700               1.0  Reciprocating
# 69           Minor  ...           A75N1               1.0  Reciprocating
# 70       Non-Fatal  ...         EMB-545               2.0  Reciprocating
# 71           Minor  ...        SA227-AT               2.0  Reciprocating
#
#    Purpose.of.flight  Total.Fatal.Injuries Total.Serious.Injuries  \
# 0           Business              0.583867                0.24362
# 1           Business              0.583867                0.24362
# 2           Business              0.583867                0.24362
# 3           Business              0.583867                0.24362
# 4           Business              0.583867                1.00000
# ..               ...                   ...                    ...
# 67          Business              0.000000                0.00000
# 68          Business              0.000000                0.00000
# 69          Business              0.000000                2.00000
# 70          Business              0.000000                0.00000
# 71          Business              0.000000                2.00000
#
#    Total.Minor.Injuries  Total.Uninjured  Weather.Condition  Year
# 0              0.309643              9.0                IMC  2005
# 1              0.309643              5.0                VMC  2005
# 2              0.309643              2.0                VMC  2005
# 3              0.309643              1.0                VMC  2005
# 4              0.309643              1.0                VMC  2005
# ..                  ...              ...                ...   ...
# 67             0.000000              1.0                VMC  2022
# 68             0.000000              3.0                NaN  2022
# 69             0.000000              2.0                VMC  2022
# 70             0.000000              4.0                VMC  2022
# 71             0.000000              1.0                IMC  2022
#
# [72 rows x 23 columns]

# %%
df_Airplanes_limited ['Total.Serious.Injuries'].value_counts()
# Out:
# 0.00000    56
# 0.24362    16
# 1.00000    10
# 2.00000     5
# 4.00000     2
# 3.00000     1
# Name: Total.Serious.Injuries, dtype: int64

# %%
# Just as for the total fatalities extract for those least injuries
df_Least_Serious_Injuries = df_Airplanes_limited[df_Airplanes_limited['Total.Serious.Injuries'] < 1]
df_Least_Serious_Injuries
# Out:
#             Event.Id Investigation.Type Accident.Number Event.Date  \
# 3118  20050211X00175           Accident      DEN05CA050 2005-01-19
# 3136  20050510X00586           Accident      DFW05LA117 2005-05-09
# 3142  20050701X00917           Accident      DEN05LA102 2005-06-29
# 3151  20050816X01251           Accident      DEN05LA123 2005-08-07
# 3161  20051003X01562           Accident      NYC05LA145 2005-09-22
# ...              ...                ...             ...        ...
# 3701  20220222104672           Accident      CEN22LA126 2022-02-18
# 3718  20220608105217           Accident      WPR22LA201 2022-06-07
# 3720  20220726105587           Accident      WPR22LA272 2022-07-13
# 3725  20220804105665           Accident      WPR22LA290 2022-08-03
# 3734  20221004106055           Accident      CEN23LA003 2022-10-03
#
#              Location        Country   Latitude    Longitude Airport.Code  \
# 3118        LOGAN, UT  United States  41.788333  -111.853333          LGU
# 3136    BROWNWOOD, TX  United States  31.793611   -98.956389          BWD
# 3142     SCOFIELD, UT  United States        NaN          NaN          NaN
# 3151  ALBUQUERQUE, NM  United States  35.403611  -106.615278          ABQ
# 3161     COLUMBUS, OH  United States  40.079723   -83.072778          OSU
# ...               ...            ...        ...          ...          ...
# 3701      Detroit, MI  United States    042256N     0008310W          DET
# 3718    Hawthorne, CA  United States    335520N     0118203W         KHHR
# 3720    Scappoose, WA  United States    454616N     1225143W          SPB
# 3725     Carlsbad, NM  United States    032201N     1041541W          CNM
# 3734      Houston, TX  United States    293844N     0951642W          HOU
#
#      Injury.Severity  ...           Model Number.of.Engines    Engine.Type  \
# 3118       Non-Fatal  ...          G-1159               2.0      Turbo Jet
# 3136       Non-Fatal  ...       NA-265-80               2.0      Turbo Fan
# 3142       Non-Fatal  ...            480B               1.0     Turbo Prop
# 3151       Non-Fatal  ...  Rutan Long EZE               1.0  Reciprocating
# 3161       Non-Fatal  ...       BK-117-B2               2.0    Turbo Shaft
# ...              ...  ...             ...               ...            ...
# 3701       Non-Fatal  ...         EMB-500               2.0      Turbo Jet
# 3718       Non-Fatal  ...      BD100 1A10               2.0    Turbo Shaft
# 3720       Non-Fatal  ...      PA-60-601P               2.0  Reciprocating
# 3725       Non-Fatal  ...         TBM 700               1.0  Reciprocating
# 3734       Non-Fatal  ...         EMB-545               2.0  Reciprocating
#
#      Purpose.of.flight  Total.Fatal.Injuries Total.Serious.Injuries  \
# 3118          Business              0.583867                0.24362
# 3136          Business              0.583867                0.24362
# 3142          Business              0.583867                0.24362
# 3151          Business              0.583867                0.24362
# 3161          Business              0.583867                0.24362
# ...                ...                   ...                    ...
# 3701          Business              0.000000                0.00000
# 3718          Business              0.000000                0.00000
# 3720          Business              0.000000                0.00000
# 3725          Business              0.000000                0.00000
# 3734          Business              0.000000                0.00000
#
#      Total.Minor.Injuries  Total.Uninjured  Weather.Condition  Year
# 3118             0.309643              9.0                IMC  2005
# 3136             0.309643              5.0                VMC  2005
# 3142             0.309643              2.0                VMC  2005
# 3151             0.309643              1.0                VMC  2005
# 3161             0.309643              5.0                VMC  2005
# ...                   ...              ...                ...   ...
# 3701             0.000000              1.0                VMC  2022
# 3718             0.000000             11.0                VMC  2022
# 3720             0.000000              1.0                VMC  2022
# 3725             0.000000              3.0                NaN  2022
# 3734             0.000000              4.0                VMC  2022
#
# [72 rows x 23 columns]

# %%
#Check for the minor injuries
df_Airplanes_limited ['Total.Minor.Injuries'].value_counts()
# Out:
# 0.000000    62
# 0.309643    17
# 1.000000     6
# 2.000000     5
# Name: Total.Minor.Injuries, dtype: int64

# %%
# Exract the data frame with least number of minor injuries
df_Least_Minor_Injuries = df_Airplanes_limited[df_Airplanes_limited['Total.Minor.Injuries'] < 1]
df_Least_Minor_Injuries.shape
# Out:
# (79, 23)

# %% [markdown]
# For the total uninjured column, find the the one with maximum number of 'Uninjured'
# for this column, the higher the number of uninjured, the safer the aircraft and hence the less risky it is.

# %%
df_Airplanes_limited ['Total.Uninjured'].value_counts()
# Out:
# 0.000000     33
# 1.000000     26
# 2.000000     12
# 5.000000      4
# 1.388563      3
# 3.000000      3
# 4.000000      2
# 7.000000      2
# 9.000000      2
# 11.000000     1
# 8.000000      1
# 12.000000     1
# Name: Total.Uninjured, dtype: int64

# %%
# Get the dataframe for those  that had highest number of uninjured, consider higher numbers
df_Total_Uninjured = df_Airplanes_limited[df_Airplanes_limited['Total.Uninjured'] >= 10]
df_Total_Uninjured
# Out:
#             Event.Id Investigation.Type Accident.Number Event.Date  \
# 3238  20080206X00140           Accident      CHI07LA317 2007-07-17
# 3718  20220608105217           Accident      WPR22LA201 2022-06-07
#
#            Location        Country Latitude Longitude Airport.Code  \
# 3238     Custer, SD  United States      NaN       NaN          NaN
# 3718  Hawthorne, CA  United States  335520N  0118203W         KHHR
#
#      Injury.Severity  ...       Model Number.of.Engines    Engine.Type  \
# 3238       Non-Fatal  ...        S81A               1.0  Reciprocating
# 3718       Non-Fatal  ...  BD100 1A10               2.0    Turbo Shaft
#
#      Purpose.of.flight  Total.Fatal.Injuries Total.Serious.Injuries  \
# 3238          Business              0.583867                    1.0
# 3718          Business              0.000000                    0.0
#
#      Total.Minor.Injuries  Total.Uninjured  Weather.Condition  Year
# 3238             0.309643             12.0                VMC  2007
# 3718             0.000000             11.0                VMC  2022
#
# [2 rows x 23 columns]

# %% [markdown]
# Now concatenate the data frames and remove the duplicates.
# Now we have a dataframe for the aircrafts under the airplane  category that are least risky
# with this data frame we now can plot to see which is the most preferable in this category.

# %%
# Now add all the above dataframes together and remove duplicates
df_Airplanes_FS = pd.concat([df_Least_fatalities, df_Least_Serious_Injuries, df_Least_Minor_Injuries, df_Total_Uninjured ], axis=0, ignore_index=True).drop_duplicates()
df_Airplanes_FS.shape
# Display the dataframe
df_Airplanes_FS
# Out:
#            Event.Id Investigation.Type Accident.Number Event.Date  \
# 0    20050211X00175           Accident      DEN05CA050 2005-01-19
# 1    20050510X00586           Accident      DFW05LA117 2005-05-09
# 2    20050701X00917           Accident      DEN05LA102 2005-06-29
# 3    20050816X01251           Accident      DEN05LA123 2005-08-07
# 4    20050831X01342           Accident      IAD05LA122 2005-08-12
# ..              ...                ...             ...        ...
# 122  20170717X15023           Accident      WPR17FA155 2017-07-17
# 127  20180530X50125           Accident      WPR18FA155 2018-05-30
# 133  20200729X52602           Accident      WPR20LA244 2020-07-29
# 135  20200828X11258           Accident      ERA20LA297 2020-08-28
# 137  20211113104239           Accident      CEN22FA031 2021-11-13
#
#               Location        Country   Latitude    Longitude Airport.Code  \
# 0            LOGAN, UT  United States  41.788333  -111.853333          LGU
# 1        BROWNWOOD, TX  United States  31.793611   -98.956389          BWD
# 2         SCOFIELD, UT  United States        NaN          NaN          NaN
# 3      ALBUQUERQUE, NM  United States  35.403611  -106.615278          ABQ
# 4       SAULSVILLE, WV  United States  37.652222       -81.45          NaN
# ..                 ...            ...        ...          ...          ...
# 122           Mesa, AZ  United States    033289N     1114247W          FFZ
# 127       Melville, NY  United States    040466N     0732325W          FRG
# 133         Pioche, NV  United States    375512N     1143224W          NaN
# 135  Pembroke Park, FL  United States    255940N     0801015W          NaN
# 137  Beaver Island, MI  United States    454312N     0085314W          6Y8
#
#     Injury.Severity  ...              Model Number.of.Engines    Engine.Type  \
# 0         Non-Fatal  ...             G-1159               2.0      Turbo Jet
# 1         Non-Fatal  ...          NA-265-80               2.0      Turbo Fan
# 2         Non-Fatal  ...               480B               1.0     Turbo Prop
# 3         Non-Fatal  ...     Rutan Long EZE               1.0  Reciprocating
# 4         Non-Fatal  ...               280C               1.0  Reciprocating
# ..              ...  ...                ...               ...            ...
# 122           Fatal  ...  Lancair Evolution               1.0     Turbo Prop
# 127           Fatal  ...              SNJ 2               1.0  Reciprocating
# 133           Fatal  ...              AS350               1.0  Reciprocating
# 135           Fatal  ...                500               2.0  Reciprocating
# 137           Fatal  ...              BN-2A               2.0  Reciprocating
#
#     Purpose.of.flight  Total.Fatal.Injuries Total.Serious.Injuries  \
# 0            Business              0.583867                0.24362
# 1            Business              0.583867                0.24362
# 2            Business              0.583867                0.24362
# 3            Business              0.583867                0.24362
# 4            Business              0.583867                1.00000
# ..                ...                   ...                    ...
# 122          Business              2.000000                0.00000
# 127          Business              1.000000                0.00000
# 133          Business              2.000000                0.00000
# 135          Business              2.000000                0.00000
# 137          Business              4.000000                0.00000
#
#     Total.Minor.Injuries  Total.Uninjured  Weather.Condition  Year
# 0               0.309643              9.0                IMC  2005
# 1               0.309643              5.0                VMC  2005
# 2               0.309643              2.0                VMC  2005
# 3               0.309643              1.0                VMC  2005
# 4               0.309643              1.0                VMC  2005
# ..                   ...              ...                ...   ...
# 122             0.000000              0.0                VMC  2017
# 127             0.000000              0.0                VMC  2018
# 133             0.000000              0.0                VMC  2020
# 135             0.000000              0.0                VMC  2020
# 137             1.000000              0.0                VMC  2021
#
# [90 rows x 23 columns]

# %%
# Check for the value counts of the concatenated dataframe
df_Airplanes_FS['Engine.Type'].value_counts()
# Out:
# Reciprocating    63
# Turbo Prop       11
# Turbo Fan         9
# Turbo Jet         4
# Turbo Shaft       2
# Electric          1
# Name: Engine.Type, dtype: int64

# %%
# Check for the shape of the new dataframe
df_Airplanes_FS.shape
# Out:
# (90, 23)

# %%
# Plot for the Make category and the number of Total.Fatal.Injuries 
# First import both seaborn and matplotlib libraries
import seaborn as sns
import matplotlib.pyplot as plt
# Sort the data for plotting purpose, it allows the organization of the plot
df_Airplanes_FS = df_Airplanes_FS.sort_values(by='Total.Fatal.Injuries', ascending=False)
# Set the style and figure size
sns.set(style='whitegrid') 
plt.figure(figsize=(12,10))
# plotb the bar graph and indicate the attributes
bar_plot = sns.barplot(data=df_Airplanes_FS, 
                       y='Make', 
                       x='Total.Fatal.Injuries',
                       hue='Aircraft.Category', 
                       linewidth=1.5, 
                       palette='viridis')
# set the plot title and the attributes
plt.title('Total Fatal Injuries; 2005 - 2022', fontsize=20, fontweight='bold', pad=20)

# label the axes
plt.xlabel('Number of Fatal Injuries', fontsize=16, fontweight='bold')
plt.ylabel('Aircraft Make', fontsize=16, fontweight='bold')

# Set both xticks and yticks for visuals of the labels
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
# set the grid
plt.grid(axis='x', linestyle='--', alpha=0.7)
# Customize the legend
plt.legend(title='Aircraft Category', loc='lower right', fontsize=12, title_fontsize='13')
# set the tight layout for better spacing
plt.tight_layout()

# %% [markdown]
# As per the plot above, the airplane make with the least number of accidents should be considered.
# The aircrafts to be considered with this plot are those with zero number of accidents.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sort the data for plotting purpose, it allows the organization of the plot
df_Airplanes_FS = df_Airplanes_FS.sort_values(by='Total.Serious.Injuries', ascending=False)
#customize the bar frame style and size
sns.set(style='dark') 
plt.figure(figsize=(10,12))

# set customs for the barplot
bar_plot = sns.barplot(data=df_Airplanes_FS, 
                       y='Make', 
                       x='Total.Serious.Injuries',
                       hue='Aircraft.Category', 
                       linewidth=1.5, 
                       palette='viridis')
# Add title and labesl
plt.title('Total.Serious.Injuries', fontsize=18, fontweight='bold')
plt.xlabel('Injuries (count)', fontsize=16, fontweight='bold')
plt.ylabel('Aircraft Make', fontsize=16, fontweight='bold')
# Adjust the ticks 
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
# Add grid lines for readability
plt.grid(axis='x', linestyle='--', alpha=0.7)
# Custom the legend
plt.legend(title='Aircraft Categories', loc='lower right', fontsize=12, title_fontsize='13')
plt.tight_layout()

# %%
import seaborn as sns

df_Airplanes_FS = df_Airplanes_FS.sort_values(by='Total.Minor.Injuries',ascending = False)
# Customize the plot
plt.figure (figsize=(10,9))
sns.barplot(data = df_Airplanes_FS, y = df_Airplanes_FS['Make'],
            x = df_Airplanes_FS['Total.Minor.Injuries'],
            hue = 'Aircraft.Category', linewidth = 1.5, palette='viridis')
# set the plot labels
plt.title('Total Minor Injuries(Airplanes)', fontsize=18, fontweight='bold')
plt.ylabel('Make')
plt.xlabel('Number of accidents')
# Customize the ticks for readability
plt.xticks(rotation = 90)
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=12)
# For spacing
plt.tight_layout()

plt.show()

# %% [markdown]
# For the total injuries plot, the aircrafts with zero number of accidents over the period
# should be considered.

# %%
df_Airplanes_FS = df_Airplanes_FS.sort_values(by='Total.Uninjured',ascending = False)

# set the plot essentials, size, type of plot and load data
plt.figure (figsize=(10,8))
sns.barplot(data = df_Airplanes_FS, x = df_Airplanes_FS['Make'], y = df_Airplanes_FS['Total.Uninjured'],
            hue = 'Aircraft.Category', linewidth = 1.5,palette='viridis', log = True)

# customize theplot labels
plt.title('Total Uninjured (Airplanes)', fontsize=18, fontweight='bold')
plt.xlabel('Aircraft Make',fontsize=16, fontweight='bold')
plt.ylabel('Number of Uninjured', fontsize=14)

# For easy reading, set the xticks
plt.xticks(rotation=90,fontsize=12)
plt.legend(title='Aircraft Category', title_fontsize='13', fontsize='11')
# add grid lines
plt.grid(axis='y', linestyle='--', linewidth=0.7)
# adjust the layout
plt.tight_layout()

plt.show()

# %% [markdown]
# In the total uninjured bargraph above, the least risky aircraft is one with the highest Total.Uninjured.
# The best best recommendation of aircraft in the airplane category will be the one with relatively high Total.Uninjured
# and be with the least number of total fatalities, total injuries and least minor injuries.
# By considering the highest five, from the total uninjured plot, and checking them through the other plots,
# I would come to conclude that the least riky aircrafts in the airplane category, and ordered from the most recommended to the least are:
# 1.Bombadier
# 2.Dassault Falcon
# 3.Israel Aircraft Industries
# 4.Embraer
